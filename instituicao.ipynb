# %%
from database.session import engine
import pandas as pd
import matplotlib.pyplot as plt

query = "SELECT * FROM grupo_de_pesquisa;"

df = pd.read_sql(query, engine)

grupo_por_area = df.groupby('nome_da_instituicao').size()


plt.figure(figsize=(15, 6)) 

grupo_por_area.plot(kind='bar')
plt.title('Contagem por Instituição')
plt.xlabel('Instituição')
plt.ylabel('Contagem')
plt.show()
# Out:
# /home/kirito/Documents/Faculdade/TCC/project/BigData_2023/venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
